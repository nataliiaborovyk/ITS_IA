# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.19.0

# %%
# ----------------------------
# Dataset CIFAR-10
# ----------------------------
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

print("Train images:", x_train.shape)  # (50000, 32, 32, 3)
print("Train labels:", y_train.shape)  # (50000, 1)
print("Test  images:", x_test.shape)   # (10000, 32, 32, 3)
print("Test  labels:", y_test.shape)   # (10000, 1)

# labels: (N,1) -> (N,)   una tupla con un solo elemento, una dimensione sola
y_train = y_train.reshape(-1)  # trasforma array in un vettore 1D
y_test  = y_test.reshape(-1)

# Normalizzazione 0-255 -> 0-1
x_train = x_train.astype("float32") / 255.0
x_test  = x_test.astype("float32") / 255.0

print("Train:", x_train.shape, y_train.shape)
print("Test :", x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# Train images: (50000, 32, 32, 3)
# Train labels: (50000, 1)
# Test  images: (10000, 32, 32, 3)
# Test  labels: (10000, 1)
# Train: (50000, 32, 32, 3) (50000,)
# Test : (10000, 32, 32, 3) (10000,)

# %%
#  10 esempi
class_names = [
    "airplane","automobile","bird","cat","deer",
    "dog","frog","horse","ship","truck"
]

plt.figure(figsize=(10, 4))
for i in range(10):
    # subplot(numero_righe, numero_colonne, posizione)
    plt.subplot(2, 5, i+1)
    plt.imshow(x_train[i])  # imshow mostra l'immagine contenuta in x_train[i]
    plt.title(class_names[y_train[i]])
    plt.axis("off")
plt.tight_layout()
plt.show()

# %%
#  Modello CNN
model = keras.Sequential([   # i layer vengono applicati uno dopo l'altro
    layers.Input(shape=(32, 32, 3)),  # le immagini in ingresso hanno forma: 32 × 32 pixel 3 canali colore (RGB)

    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
    #layers.RandomTranslation(0.1,0.1),

    layers.Conv2D(32, (3, 3), activation="relu", padding="same"), # layer di convoluzione bidimensionale
                                                                  # 32 numero di filtri (feature maps), (3,3) Dimensione del filtro.
                                                                  # padding="same" Serve per mantenere la stessa dimensione spaziale.
    layers.MaxPooling2D((2, 2)),   # Il pooling riduce la dimensione dell'immagine 32 × 32 → 16 × 16

    layers.Conv2D(128, (3, 3), activation="relu", padding="same"),
    layers.MaxPooling2D((2, 2)),   # 16 × 16 → 8 × 8

    layers.Conv2D(128, (3, 3), activation="relu", padding="same"),
    #layers.MaxPooling2D((2, 2)),  # 8 × 8 → 4 × 4

    layers.Flatten(),   # Trasforma il tensore 3D in un vettore da 4 × 4 × 128 in 2048
    layers.Dense(128, activation="relu"),  # ogni neurone è collegato a tutti gli input
    #layers.Dense(64, activation="relu"),  # ogni neurone è collegato a tutti gli input
    layers.Dropout(0.2),   # 30% dei neuroni viene disattivato casualmente
    layers.Dense(10, activation="softmax")  # softmax trasforma i valori in probabilità
])

model.summary()  # Stampa la struttura della rete
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 32, 32, 3)      │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 128)    │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,048,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,235,466 (4.71 MB)
#  Trainable params: 1,235,466 (4.71 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# ----------------------------
#  Compile
# ----------------------------
model.compile(
    optimizer="adam",  # come aggiornano i pesi
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# ----------------------------
#  Callbacks: EarlyStopping + ModelCheckpoint
# ----------------------------
early_stop = EarlyStopping(
    monitor="val_loss",          # guardo la loss di validation
    patience=3,                  # se per 3 epoche non migliora -> stop
    restore_best_weights=True    # rimette i pesi migliori
)

checkpoint = ModelCheckpoint(
    filepath="best_cifar10_model.keras",  # file salvato su disco
    monitor="val_loss",
    save_best_only=True,                 # salva solo se migliora
    verbose=1
)

# ----------------------------
#  Fit
# ----------------------------
history = model.fit(
    x_train, y_train,
    epochs=50,                 # mettiamo alto, early stopping fermerà prima
    batch_size=128,
    validation_split=0.1,
    callbacks=[early_stop, checkpoint],
    verbose=1
)

print("\nChiavi history:", history.history.keys())
# Out:
# Epoch 1/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3067 - loss: 1.8707
# Epoch 1: val_loss improved from None to 1.34906, saving model to best_cifar10_model.keras
#
# Epoch 1: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - accuracy: 0.3957 - loss: 1.6510 - val_accuracy: 0.5138 - val_loss: 1.3491
# Epoch 2/50
# 350/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5091 - loss: 1.3620
# Epoch 2: val_loss improved from 1.34906 to 1.09885, saving model to best_cifar10_model.keras
#
# Epoch 2: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5304 - loss: 1.3136 - val_accuracy: 0.6036 - val_loss: 1.0988
# Epoch 3/50
# 349/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5688 - loss: 1.2057
# Epoch 3: val_loss did not improve from 1.09885
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.5807 - loss: 1.1801 - val_accuracy: 0.6106 - val_loss: 1.1082
# Epoch 4/50
# 348/352 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6098 - loss: 1.1035
# Epoch 4: val_loss improved from 1.09885 to 0.95516, saving model to best_cifar10_model.keras
#
# Epoch 4: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.6184 - loss: 1.0797 - val_accuracy: 0.6642 - val_loss: 0.9552
# Epoch 5/50
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6330 - loss: 1.0376
# Epoch 5: val_loss improved from 0.95516 to 0.85437, saving model to best_cifar10_model.keras
#
# Epoch 5: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6418 - loss: 1.0137 - val_accuracy: 0.7078 - val_loss: 0.8544
# Epoch 6/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6618 - loss: 0.9550
# Epoch 6: val_loss did not improve from 0.85437
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6639 - loss: 0.9546 - val_accuracy: 0.6992 - val_loss: 0.8922
# Epoch 7/50
# 347/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6800 - loss: 0.9061
# Epoch 7: val_loss improved from 0.85437 to 0.84772, saving model to best_cifar10_model.keras
#
# Epoch 7: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6815 - loss: 0.9059 - val_accuracy: 0.7142 - val_loss: 0.8477
# Epoch 8/50
# 350/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6919 - loss: 0.8767
# Epoch 8: val_loss improved from 0.84772 to 0.79204, saving model to best_cifar10_model.keras
#
# Epoch 8: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6945 - loss: 0.8677 - val_accuracy: 0.7308 - val_loss: 0.7920
# Epoch 9/50
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7099 - loss: 0.8255
# Epoch 9: val_loss did not improve from 0.79204
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7084 - loss: 0.8362 - val_accuracy: 0.7288 - val_loss: 0.8067
# Epoch 10/50
# 350/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7158 - loss: 0.8071
# Epoch 10: val_loss improved from 0.79204 to 0.75365, saving model to best_cifar10_model.keras
#
# Epoch 10: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7200 - loss: 0.7986 - val_accuracy: 0.7430 - val_loss: 0.7537
# Epoch 11/50
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7298 - loss: 0.7702
# Epoch 11: val_loss improved from 0.75365 to 0.73200, saving model to best_cifar10_model.keras
#
# Epoch 11: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7308 - loss: 0.7718 - val_accuracy: 0.7502 - val_loss: 0.7320
# Epoch 12/50
# 350/352 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7430 - loss: 0.7366
# Epoch 12: val_loss improved from 0.73200 to 0.71264, saving model to best_cifar10_model.keras
#
# Epoch 12: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7393 - loss: 0.7451 - val_accuracy: 0.7600 - val_loss: 0.7126
# Epoch 13/50
# 350/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7451 - loss: 0.7141
# Epoch 13: val_loss did not improve from 0.71264
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7425 - loss: 0.7269 - val_accuracy: 0.7502 - val_loss: 0.7449
# Epoch 14/50
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7530 - loss: 0.7032
# Epoch 14: val_loss improved from 0.71264 to 0.68184, saving model to best_cifar10_model.keras
#
# Epoch 14: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7545 - loss: 0.7011 - val_accuracy: 0.7734 - val_loss: 0.6818
# Epoch 15/50
# 347/352 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7617 - loss: 0.6809
# Epoch 15: val_loss improved from 0.68184 to 0.67792, saving model to best_cifar10_model.keras
#
# Epoch 15: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.7598 - loss: 0.6874 - val_accuracy: 0.7730 - val_loss: 0.6779
# Epoch 16/50
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7655 - loss: 0.6656
# Epoch 16: val_loss improved from 0.67792 to 0.65090, saving model to best_cifar10_model.keras
#
# Epoch 16: finished saving model to best_cifar10_model.keras
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.7672 - loss: 0.6653 - val_accuracy: 0.7824 - val_loss: 0.6509
# Epoch 17/50
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7726 - loss: 0.6406
# Epoch 17: val_loss did not improve from 0.65090
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7732 - loss: 0.6450 - val_accuracy: 0.7736 - val_loss: 0.6869
# Epoch 18/50
# 348/352 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7808 - loss: 0.6230
# Epoch 18: val_loss did not improve from 0.65090
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.7779 - loss: 0.6347 - val_accuracy: 0.7688 - val_loss: 0.6970
# Epoch 19/50
# 351/352 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7841 - loss: 0.6090
# Epoch 19: val_loss did not improve from 0.65090
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7831 - loss: 0.6188 - val_accuracy: 0.7632 - val_loss: 0.7166
#
# Chiavi history: dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
# ----------------------------
#  Evaluate sul test (modello in RAM)
# ----------------------------
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print("\nTEST (model in RAM):")
print("test_loss =", test_loss)
print("test_acc  =", test_acc)
# Out:
# TEST (model in RAM):
# test_loss = 0.6755191683769226
# test_acc  = 0.7712000012397766

# %%
# ----------------------------
#  Carico il best model dal file e rivaluto
# ----------------------------
best_model = keras.models.load_model("best_cifar10_model.keras")
best_test_loss, best_test_acc = best_model.evaluate(x_test, y_test, verbose=0)

print("\nTEST (BEST model da file):")
print("best_test_loss =", best_test_loss)
print("best_test_acc  =", best_test_acc)
# Out:
# TEST (BEST model da file):
# best_test_loss = 0.6755191683769226
# best_test_acc  = 0.7712000012397766

# %%
#  Predizioni su 10 immagini test
indices = np.random.choice(len(x_test), size=10, replace=False)

plt.figure(figsize=(12, 6))
for i, idx in enumerate(indices):
      # enumerate() restituisce due valori: i   → posizione nel ciclo (0..9)  idx → indice reale dell'immagine nel dataset
    img = x_test[idx]
    true_label = y_test[idx]
    pred = model.predict(img[np.newaxis, ...], verbose=0)[0]
        # modello riceve i dati (batch_size, 32, 32, 3)
        # img[np.newaxis, ...] aggiunge una dimensione davanti.
    pred_label = int(np.argmax(pred))   # argmax trova l'indice del valore massimo
    confidence = float(pred[pred_label] * 100)

    plt.subplot(2, 5, i+1)
    plt.imshow(img)
    color = "green" if pred_label == true_label else "red"
    plt.title(f"True: {class_names[true_label]}\nPred: {class_names[pred_label]} ({confidence:.1f}%)",
              color=color)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# ----------------------------
#  Grafici training (loss / acc)
# ----------------------------
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="train acc")
plt.plot(history.history["val_accuracy"], label="val acc")
# y = history.history["val_accuracy"]
# x = 0,1,2,3,4,...,N  matplotlib crea automaticamente l'asse X (numero di epoca)
plt.title("Accuracy")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="train loss")
plt.plot(history.history["val_loss"], label="val loss")
plt.title("Loss")
plt.legend()
plt.grid(True)

plt.show()

print("\nFile salvato:", "best_cifar10_model.keras")
# Out:
# File salvato: best_cifar10_model.keras
